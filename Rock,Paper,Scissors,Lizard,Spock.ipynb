# %%
#identify possible inputs in an array
import random
import sys 

# list of all possilbe cpu cases 
inputs = ["rock", "paper", "scissors", "lizard", "spock"]

# save the inputs as strings 
R = "rock"
P = "paper"
S = "scissors"
L = "lizard"
SP = "spock"

# computer will first pick a random string 
computer_input = random.choice(inputs)

# prompt the user to type
user_input = input('Enter your input: ').casefold() # if the user enters a capital letter
# display results and see who won
print('computer choice: ', computer_input.capitalize())
print('\n')
# write if statements for every possible scenario
if user_input == computer_input:
  print("It's a Tie!") 
if user_input == S and computer_input == P:
  print("You Won!") 

if user_input == S and computer_input == L:
  print("You Won!") 

if user_input == S and computer_input == R:
  print("You Lost!") 

if user_input == S and computer_input == SP:
  print("You Lost!") 

if user_input == P and computer_input == R:
  print("You Won!") 

if user_input == P and computer_input == SP:
  print("You Won!") 

if user_input == P and computer_input == S:
  print("You Lost!") 

if user_input == P and computer_input == L:
  print("You Lost!") 

if user_input == R and computer_input == S:
  print("You Won!") 

if user_input == R and computer_input == L:
  print("You Won!") 

if user_input == R and computer_input == SP:
  print("You Lost!") 

if user_input == R and computer_input == P:
  print("You Lost!") 

if user_input == L and computer_input == P:
  print("You Won!")

if user_input == L and computer_input == SP:
  print("You Won!")

if user_input == L and computer_input == S:
  print("You Lost!")

if user_input == L and computer_input == R:
  print("You Lost")

if user_input == SP and computer_input == R:
  print("You Won!")

if user_input == SP and computer_input == S:
  print("You Won!")

if user_input == SP and computer_input == L:
  print("You Lost!")

if user_input == SP and computer_input == P:
  print("You Lost!")
# Out:
# Enter your input: scissors
# computer choice:  Spock
#
#
# You Lost!
